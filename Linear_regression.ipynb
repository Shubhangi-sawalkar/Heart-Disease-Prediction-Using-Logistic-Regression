# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubhangi-sawalkar/Heart-Disease-Prediction-Using-Logistic-Regression/blob/main/Linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
df = pd.read_csv("Iris.csv")

# %%
df
# Out:
#       id  sepal_length  sepal_width  petal_length  petal_width           label
# 0      1           5.1          3.5           1.4          0.2     Iris-setosa
# 1      2           4.9          3.0           1.4          0.2     Iris-setosa
# 2      3           4.7          3.2           1.3          0.2     Iris-setosa
# 3      4           4.6          3.1           1.5          0.2     Iris-setosa
# 4      5           5.0          3.6           1.4          0.2     Iris-setosa
# ..   ...           ...          ...           ...          ...             ...
# 145  146           6.7          3.0           5.2          2.3  Iris-virginica
# 146  147           6.3          2.5           5.0          1.9  Iris-virginica
# 147  148           6.5          3.0           5.2          2.0  Iris-virginica
# 148  149           6.2          3.4           5.4          2.3  Iris-virginica
# 149  150           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df.head()
# Out:
#    id  sepal_length  sepal_width  petal_length  petal_width        label
# 0   1           5.1          3.5           1.4          0.2  Iris-setosa
# 1   2           4.9          3.0           1.4          0.2  Iris-setosa
# 2   3           4.7          3.2           1.3          0.2  Iris-setosa
# 3   4           4.6          3.1           1.5          0.2  Iris-setosa
# 4   5           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.describe()
# Out:
#                id  sepal_length  sepal_width  petal_length  petal_width
# count  150.000000    150.000000   150.000000    150.000000   150.000000
# mean    75.500000      5.843333     3.054000      3.758667     1.198667
# std     43.445368      0.828066     0.433594      1.764420     0.763161
# min      1.000000      4.300000     2.000000      1.000000     0.100000
# 25%     38.250000      5.100000     2.800000      1.600000     0.300000
# 50%     75.500000      5.800000     3.000000      4.350000     1.300000
# 75%    112.750000      6.400000     3.300000      5.100000     1.800000
# max    150.000000      7.900000     4.400000      6.900000     2.500000

# %%
df.isnull().sum()
# Out:
# id               0
# sepal_length     0
# sepal_width      0
# petal_length     0
# petal_width      0
# label            0
# label_encoded    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['label'] = le.fit_transform(df['label'])

# %%
x=df.iloc[:,:-1]
x
# Out:
#       id  sepal_length  sepal_width  petal_length  petal_width
# 0      1           5.1          3.5           1.4          0.2
# 1      2           4.9          3.0           1.4          0.2
# 2      3           4.7          3.2           1.3          0.2
# 3      4           4.6          3.1           1.5          0.2
# 4      5           5.0          3.6           1.4          0.2
# ..   ...           ...          ...           ...          ...
# 145  146           6.7          3.0           5.2          2.3
# 146  147           6.3          2.5           5.0          1.9
# 147  148           6.5          3.0           5.2          2.0
# 148  149           6.2          3.4           5.4          2.3
# 149  150           5.9          3.0           5.1          1.8
#
# [150 rows x 5 columns]

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: label, Length: 150, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#       id  sepal_length  sepal_width  petal_length  petal_width
# 22    23           4.6          3.6           1.0          0.2
# 15    16           5.7          4.4           1.5          0.4
# 65    66           6.7          3.1           4.4          1.4
# 11    12           4.8          3.4           1.6          0.2
# 42    43           4.4          3.2           1.3          0.2
# ..   ...           ...          ...           ...          ...
# 71    72           6.1          2.8           4.0          1.3
# 106  107           4.9          2.5           4.5          1.7
# 14    15           5.8          4.0           1.2          0.2
# 92    93           5.8          2.6           4.0          1.2
# 102  103           7.1          3.0           5.9          2.1
#
# [120 rows x 5 columns]

# %%
y_train
# Out:
# 22     0
# 15     0
# 65     1
# 11     0
# 42     0
#       ..
# 71     1
# 106    2
# 14     0
# 92     1
# 102    2
# Name: label, Length: 120, dtype: int64

# %%
# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform label encoding on the target variable
df['label_encoded'] = label_encoder.fit_transform(df['label'])

# Define your feature variable X
X_train = df[['label']]

# Define your target variable y as the label_encoded column
y_train = df['label_encoded']

# Create and train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Create and train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()
